# %%
mylist = ["MCA", "MBA", "Msc"]
print(mylist)
x = mylist[-2]
x
# Out:
# ['MCA', 'MBA', 'Msc']
# 'MBA'

# %%
list= ["a","b","c","d","e"]
print(list[-5:-2])   # start value and end value
# Out:
# ['a', 'b', 'c']

# %% [markdown]
# TUPLES

# %%
mytuple=("Mca", "Mba", "Msc")
print(mytuple)
x = mytuple[1]
x
# Out:
# ('Mca', 'Mba', 'Msc')
# 'Mba'

# %% [markdown]
# Dictonary

# %%
thisdict = {
  "srm": "rmp",
  "MCA": "A",
  "MBA": "B"
}
print(thisdict["srm"])
# Out:
# rmp

# %% [markdown]
# Sets

# %%
mysets={"MCA","MBA","Msc"}
print(mysets)
# Out:
# {'MCA', 'MBA', 'Msc'}

# %%
mylists=["MCA","MBA","msc"]
print(type(mylists))
# Out:
# <class 'list'>

# %% [markdown]
# Variable

# %%
x=10;
y=20;
c = x+y
print(type(c))
# Out:
# <class 'int'>

# %% [markdown]
# Data types

# %%
# x=str("lalith")
# print(x)
str = "lalith"
str
print(type(str))
# Out:
# <class 'str'>

# %%
float=111.11
float
print(type(float))
# Out:
# <class 'float'>

# %%
x=bool(1)
print(x)
# Out:
# True

# %%
x=bool(True)
print(x)
# Out:
# True

# %%
complex=(5j)
print(complex)
# Out:
# 5j

# %%
int=100
print(int)
# Out:
# 100

# %%
mytuple=("q","b","c")
print(type(mytuple))
# Out:
# <class 'tuple'>
